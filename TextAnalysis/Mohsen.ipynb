# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('kanoon.xlsx')

# %%
comments = df['Comment'].values
df['my_answer'] = np.zeros(len(df))

# %%
names = df.columns
new_names = []
for i in range(len(names)):
    if i ==9:
        new_names.append('my_answer')
    elif i<9:
        new_names.append(names[i])
    else :
        new_names.append(names[i-1])
df = df[new_names]
new_names
# Out:
# ['CodeComment',
#  'CodeMaghta',
#  'shenase',
#  'KarbarName',
#  'SoalPasokh',
#  'Comment',
#  'BarrasiKonande',
#  'TarikheBarrasi',
#  1,
#  'my_answer',
#  2,
#  3,
#  4,
#  'Mabhas',
#  'virayesh',
#  'PasokhPishnehadi',
#  'Tarikh',
#  'Codejavab',
#  'saateersal',
#  'Shomarande']

# %%
for ind , i in enumerate(comments):
    if len(i)<10:
        df['my_answer'][ind]= 'نامرتبط (متفرقه)'
# Out:
# <ipython-input-9-dc349f430cda>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['my_answer'][ind]= 'نامرتبط (متفرقه)'

# %%
f=df['my_answer']
c=0
for i in range(len(f)):
    if f[i]!=0:
        c+=1
c
# Out:
# 233

# %%
df
# Out:
#       CodeComment                                         CodeMaghta  \
# 0        10440194  http://www.kanoon.ir/Amoozesh/Video/23-2-2348-...
# 1        10436946  http://www.kanoon.ir/Amoozesh/Video/27-1-37755...
# 2        10439534   http://www.kanoon.ir/Amoozesh/Video/45-1-33656-2
# 3        10438841  http://www.kanoon.ir/Amoozesh/Video/31-1-25082...
# 4        10441006  http://www.kanoon.ir/Amoozesh/Video/24-1-51093...
# ...           ...                                                ...
# 4359     10442071    http://www.kanoon.ir/Public/Entrance?mc=7&gc=17
# 4360     10442078     http://www.kanoon.ir/Public/Entrance?mc=1&gc=4
# 4361     10442083     http://www.kanoon.ir/Public/Entrance?mc=1&gc=4
# 4362     10442085  http://www.kanoon.ir/Amoozesh/Video/31-1-29384...
# 4363     10442091     http://www.kanoon.ir/Public/Entrance?mc=1&gc=8
#
#        shenase                                         KarbarName  SoalPasokh  \
# ...
