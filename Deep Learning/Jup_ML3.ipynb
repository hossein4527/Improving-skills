# %%
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

# %% [markdown]
# # Data

# %%
mnist_data , mnist_data_info = tfds.load(name='mnist' , with_info=True)
# Out:
# -------------------------------------------------------------
# ValueError                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/tensorflow_datasets/core/utils/py_utils.py in try_reraise(*args, **kwargs)
#     381   try:
# --> 382     yield
#     383   except Exception:   # pylint: disable=broad-except
#
# ~/.local/lib/python3.8/site-packages/tensorflow_datasets/core/registered.py in builder(name, **builder_init_kwargs)
#     243       prefix="Failed to construct dataset {}".format(name)):
# --> 244     return builder_cls(name)(**builder_kwargs)
#     245
#
# ~/.local/lib/python3.8/site-packages/tensorflow_datasets/core/api_utils.py in disallow_positional_args_dec(fn, instance, args, kwargs)
#      68     _check_required(fn, kwargs)
# ---> 69     return fn(*args, **kwargs)
#      70
#
# ~/.local/lib/python3.8/site-packages/tensorflow_datasets/core/dataset_builder.py in __init__(self, data_dir, config, version)
# ...
